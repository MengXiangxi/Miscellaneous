# %%
def q2(q):
  if q[2]==0 and q[5]==2:
    return True
  elif q[2]==1 and q[5]==3:
    return True
  elif q[2]==2 and q[5]==0:
    return True
  elif q[2]==3 and q[5]==1:
    return True
  else:
    return False
  
def q3(q):
  if q[3]==0:
    if q[2]==q[4] and q[4]==q[6] and q[2]!=0:
      return True
    else:
      return False
  elif q[3]==1:
    if q[2]==1 and q[4]==1 and q[6]!=1:
      return True
    else:
      return False
  elif q[3]==2:
    if q[4]==2 and q[6]==2 and q[2]!=2:
      return True
    else:
      return False
  elif q[3]==3:
    if q[2]==3 and q[6]==3 and q[4]!=3:
      return True
    else:
      return False
    
def q4(q):
  if q[4]==0 and q[1]==q[5]:
    return True
  elif q[4]==1 and q[2]==q[7]:
    return True
  elif q[4]==2 and q[1]==q[9]:
    return True
  elif q[4]==3 and q[6]==q[10]:
    return True
  else:
    return False
  
def q5(q):
  if q[5]==0 and q[8]==0:
    return True
  elif q[5]==1 and q[4]==1:
    return True
  elif q[5]==2 and q[9]==2:
    return True
  elif q[5]==3 and q[7]==3:
    return True
  else:
    return False
  
def q6(q):
  if q[6]==0 and q[2]==q[8] and q[4]==q[8]:
    return True
  elif q[6]==1 and q[1]==q[8] and q[6]==q[8]:
    return True
  elif q[6]==2 and q[3]==q[8] and q[10]==q[8]:
    return True
  elif q[6]==3 and q[5]==q[8] and q[9]==q[8]:
    return True
  else:
    return False
  
def q7(q):
  a=0
  b=0
  c=0
  d=0
  for i in q:
    if q[i]==0:
      a+=1
    elif q[i]==1:
      b+=1
    elif q[i]==2:
      c+=1
    elif q[i]==3:
      d+=1
  if a<=b and a<=c and a<=d and q[7]==2:
    return True
  elif b<=a and b<=c and b<=d and q[7]==1:
    return True
  elif c<=a and c<=b and c<=d and q[7]==0:
    return True
  elif d<=a and d<=b and d<=c and q[7]==3:
    return True
  else:
    return False

def q8(q):
  nachbar = {0:[0,2,3],
             1:[1,3],
             2:[0,2],
             3:[0,1,3]}
  if q[8]==0 and (q[7] in nachbar[q[1]]):
    return True
  elif q[8]==1 and (q[5] in nachbar[q[1]]):
    return True
  elif q[8]==2 and (q[2] in nachbar[q[1]]):
    return True
  elif q[8]==3 and (q[10] in nachbar[q[1]]):
    return True
  else:
    return False
  
def q9(q):
  if q[1]==q[6]:
    if q[5]!=q[6] and q[9]==0:
      return True
    elif q[5]!=q[10] and q[9]==1:
      return True
    elif q[5]!=q[2] and q[9]==2:
      return True
    elif q[5]!=q[9] and q[9]==3:
      return True
    else:
      return False
  else:
    if q[5]==q[6] and q[9]==0:
      return True
    elif q[5]==q[10] and q[9]==1:
      return True
    elif q[5]==q[2] and q[98]==2:
      return True
    elif q[5]==q[9] and q[9]==3:
      return True
    else:
      return False
  
def q10(q):
  a=0
  b=0
  c=0
  d=0
  for i in q:
    if q[i]==0:
      a+=1
    elif q[i]==1:
      b+=1
    elif q[i]==2:
      c+=1
    elif q[i]==3:
      d+=1
  n_diff = max({a,b,c,d})-min({a,b,c,d})
  if q[10]==0 and n_diff==3:
    return True
  elif q[10]==1 and n_diff==2:
    return True
  elif q[10]==2 and n_diff==4:
    return True
  elif q[10]==3 and n_diff==1:
    return True
  else:
    return False
  
def check(q):
  if q2(q)==False:
    return
  elif q3(q)==False:
    return
  elif q4(q)==False:
    return
  elif q5(q)==False:
    return
  elif q6(q)==False:
    return
  elif q7(q)==False:
    return
  elif q8(q)==False:
    return
  elif q9(q)==False:
    return
  elif q10(q)==False:
    return
  else:
    print(q)
    return

# %%
# %%time

q = {}
for i1 in range(4):
  q[1] = i1
  for i2 in range(4):
    q[2] = i2
    for i3 in range(4):
      q[3] = i3
      for i4 in range(4):
        q[4] = i4
        for i5 in range(4):
          q[5] = i5
          for i6 in range(4):
            q[6] = i6
            for i7 in range(4):
              q[7] = i7
              for i8 in range(4):
                q[8] = i8
                for i9 in range(4):
                  q[9] = i9
                  for i10 in range(4):
                    q[10] = i10
                    check(q)
                    next
# Out:
# {1: 1, 2: 2, 3: 0, 4: 2, 5: 0, 6: 2, 7: 3, 8: 0, 9: 1, 10: 0}
# CPU times: user 648 ms, sys: 0 ns, total: 648 ms
# Wall time: 651 ms
